# %%
import openai

# %%
#!pip show openai

# %%
# Save the Generated API Key with a Variable Name
Gen_Learn = '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'
client = openai.OpenAI(api_key = Gen_Learn)

# %%
response = client.chat.completions.create(model = "gpt-3.5-turbo",
                             messages = [{"role" : "user",
                                        "content" : "Need 3 Ideas to build an Application using OpenAI APIs"}])

# %%
print(response.choices[0].message.content)
# Out:
# 1. Virtual writing assistant: Create an application that uses OpenAI's natural language generation capabilities to provide users with automated writing suggestions, grammar corrections, and content ideas for various types of writing, such as emails, essays, blog posts, and more. Users could input their writing prompts or drafts, and the app would generate suggestions and improvements to help them enhance their writing skills.
#
# 2. Personalized recommendation engine: Develop an application that utilizes OpenAI's language processing capabilities to analyze users' preferences, interests, and behaviors in order to deliver personalized recommendations for products, services, movies, books, and more. The app could use machine learning algorithms to continuously refine its recommendations based on user feedback and interactions, providing a tailored browsing experience for each individual user.
#
# 3. Interactive storytelling platform: Create an application that allows users to collaboratively write and generate interactive stories using OpenAI's text generation technology. Users could contribute to the plot, characters, and dialogue of the story, and the app would dynamically generate new story elements based on their inputs, creating a unique and engaging storytelling experience. Additionally, users could explore different story paths, make decisions that impact the outcome of the story, and share their creations with others.
